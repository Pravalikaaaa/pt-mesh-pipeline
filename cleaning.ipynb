# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt

# %%
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'all_flow_classes.csv', 'api.py', 'a_tags_data.csv', 'books.csv', 'books.py', 'china1.py', 'china2.py', 'chinabidding.csv', 'cit.csv', 'cit.py', 'cleaning.ipynb', 'datacleaning.py', 'etenders.csv', 'etenders_data.csv', 'etenders_td_data.csv', 'fiestresults.csv', 'fiestresults1.csv', 'geocode.ipynb', 'ggzy_data.csv', 'links.csv', 'main.py', 'main1.py', 'main2.py', 'metadataparser.py', 'oda-like_flows.csv', 'oof-like_flows.csv', 'products.csv', 'products.py', 'project_descriptions_and_sources.csv', 'quotes.csv', 'quotes.py', 'quotes_contents.py', 'README--Geocoded_Global_Chinese_Official_Finance.pdf', 'scraper.py', 'scraper_tender.csv', 'scrape_api.py', 'scrape_result.csv', 'standardization.ipynb', 'table_tags_data.csv', 'Taiyo.AI_Data Engineering Task (1).pdf', 'taiyo.py', 'taiyo1.py', 'taiyo2.py', 'taiyo4.py', 'taiyo5.py', 'taiyomain.csv', 'taiyomain.py', 'tender_data.csv', 'test.ipynb', 'vague_flows.csv']

# %%
df=pd.read_csv("all_flow_classes.csv")

# %%
df.head()
# Out:
#    project_id project_location_id  precision_code  geoname_id  place_name  \
# 0           1           1_2377450               1     2377450  Nouakchott
# 1           1           1_2376719               1     2376719    Sélibaby
# 2           1           1_2378538               1     2378538       Kiffa
# 3           1           1_2378080               6     2378080  Mauritania
# 4           3           3_2377450               1     2377450  Nouakchott
#
#    latitude  longitude location_type_code  \
# 0  18.08581  -15.97850               PPLC
# 1  15.15846  -12.18430               PPLA
# 2  16.61659  -11.40453               PPLA
# 3       NaN        NaN               PCLI
# 4  18.08581  -15.97850               PPLC
#
#                               location_type_name  \
# 0                  capital of a political entity
# 1  seat of a first-order administrative division
# 2  seat of a first-order administrative division
# 3                   independent political entity
# ...

# %%
df.columns
# Out:
# Index(['project_id', 'project_location_id', 'precision_code', 'geoname_id',
#        'place_name', 'latitude', 'longitude', 'location_type_code',
#        'location_type_name', 'gazetteer_adm_code', 'gazetteer_adm_name',
#        'location_class', 'geographic_exactness', 'project_title',
#        'start_actual_isodate', 'end_actual_isodate', 'donors_iso3',
#        'recipients', 'recipients_iso3', 'ad_sector_codes', 'ad_sector_names',
#        'ad_purpose_codes', 'ad_purpose_names', 'status',
#        'transactions_start_year', 'transactions_end_year',
#        'project_total_commitments', 'total_disbursements',
#        'even_split_commitments', 'even_split_disbursements',
#        'recommended_for_research', 'umbrella', 'year', 'year_uncertain',
#        'crs_sector_code', 'crs_sector_name', 'flow', 'all_recipients',
#        'recipient_condensed', 'sources_count', 'funding_agency',
#        'cofinancing_agency', 'implementing_agency', 'recipient_agencies',
# ...

# %%
df.isnull().sum()
# Out:
# project_id                 0
# project_location_id        0
# precision_code             0
# geoname_id                 0
# place_name                 0
#                         ...
# location_details        3087
# contacts                3185
# source_triangulation       0
# field_completeness         0
# round_coded                0
# Length: 78, dtype: int64

# %%
mv=["NaN",np.nan]
df=pd.read_csv("all_flow_classes.csv",na_values=mv)

# %%
df.isnull().sum()
# Out:
# project_id                 0
# project_location_id        0
# precision_code             0
# geoname_id                 0
# place_name                 0
#                         ...
# location_details        3087
# contacts                3185
# source_triangulation       0
# field_completeness         0
# round_coded                0
# Length: 78, dtype: int64

# %%
df1=df.dropna()
df1.isnull().sum()
# Out:
# project_id              0.0
# project_location_id     0.0
# precision_code          0.0
# geoname_id              0.0
# place_name              0.0
#                        ...
# location_details        0.0
# contacts                0.0
# source_triangulation    0.0
# field_completeness      0.0
# round_coded             0.0
# Length: 78, dtype: float64

# %%
df
# Out:
#       project_id project_location_id  precision_code  geoname_id  \
# 0              1           1_2377450               1     2377450
# 1              1           1_2376719               1     2376719
# 2              1           1_2378538               1     2378538
# 3              1           1_2378080               6     2378080
# 4              3           3_2377450               1     2377450
# ...          ...                 ...             ...         ...
# 6185       48940        48940_927384               8      927384
# 6186       49081       49081_7521311               4     7521311
# 6187       49081       49081_1721906               1     1721906
# 6188       49081       49081_1715348               1     1715348
# 6189       49081       49081_1694008               8     1694008
#
#                    place_name  latitude  longitude location_type_code  \
# 0                  Nouakchott  18.08581  -15.97850               PPLC
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6190 entries, 0 to 6189
# Data columns (total 78 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   project_id                 6190 non-null   int64
#  1   project_location_id        6190 non-null   object
#  2   precision_code             6190 non-null   int64
#  3   geoname_id                 6190 non-null   int64
#  4   place_name                 6190 non-null   object
#  5   latitude                   4564 non-null   float64
#  6   longitude                  4564 non-null   float64
#  7   location_type_code         6190 non-null   object
#  8   location_type_name         6190 non-null   object
#  9   gazetteer_adm_code         6190 non-null   object
#  10  gazetteer_adm_name         6190 non-null   object
#  11  location_class             6190 non-null   int64
#  12  geographic_exactness       6190 non-null   int64
# ...

# %%
df.groupby('round_coded')['round_coded'].agg("count")
# Out:
# round_coded
# AdditionalCoded          3131
# ChinatoAfrica            1521
# EcologicallySensitive    1538
# Name: round_coded, dtype: int64

# %%
df['round_coded'].unique()
# Out:
# array(['ChinatoAfrica', 'AdditionalCoded', 'EcologicallySensitive'],
#       dtype=object)

# %%
df['round_coded']=df['round_coded'].str.replace("ChinatoAfrica","china")

# %%
df
# Out:
#       project_id project_location_id  precision_code  geoname_id  \
# 0              1           1_2377450               1     2377450
# 1              1           1_2376719               1     2376719
# 2              1           1_2378538               1     2378538
# 3              1           1_2378080               6     2378080
# 4              3           3_2377450               1     2377450
# ...          ...                 ...             ...         ...
# 6185       48940        48940_927384               8      927384
# 6186       49081       49081_7521311               4     7521311
# 6187       49081       49081_1721906               1     1721906
# 6188       49081       49081_1715348               1     1715348
# 6189       49081       49081_1694008               8     1694008
#
#                    place_name  latitude  longitude location_type_code  \
# 0                  Nouakchott  18.08581  -15.97850               PPLC
# ...

# %%
df['round_coded'].unique()
# Out:
# array(['china', 'AdditionalCoded', 'EcologicallySensitive'], dtype=object)

# %%
sns.boxplot(df["geoname_id"])
# Out:
# C:\Users\manas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='geoname_id'>

# %%
max_id=df["geoname_id"].quantile(0.995)
max_id
# Out:
# 11612602.055

# %%
df[df["geoname_id"]>max_id]
# Out:
#       project_id project_location_id  precision_code  geoname_id  \
# 1404       13823      13823_11749702               1    11749702
# 3023       33437      33437_11746420               1    11746420
# 3209       34344      34344_11612603               1    11612603
# 4196       36730      36730_11746425               1    11746425
# 4325       37674      37674_11668436               1    11668436
# 4412       37880      37880_11695066               1    11695066
# 4675       38606      38606_11612609               1    11612609
# 4676       38611      38611_11612615               1    11612615
# 5049       39211      39211_11668487               1    11668487
# 5050       39211      39211_11668488               1    11668488
# 5149       39403      39403_11694492               1    11694492
# 5201       39708      39708_11612670               1    11612670
# 5285       39984      39984_11612606               1    11612606
# ...

# %%
df1=df[df["geoname_id"]<max_id]
df1
# Out:
#       project_id project_location_id  precision_code  geoname_id  \
# 0              1           1_2377450               1     2377450
# 1              1           1_2376719               1     2376719
# 2              1           1_2378538               1     2378538
# 3              1           1_2378080               6     2378080
# 4              3           3_2377450               1     2377450
# ...          ...                 ...             ...         ...
# 6185       48940        48940_927384               8      927384
# 6186       49081       49081_7521311               4     7521311
# 6187       49081       49081_1721906               1     1721906
# 6188       49081       49081_1715348               1     1715348
# 6189       49081       49081_1694008               8     1694008
#
#                    place_name  latitude  longitude location_type_code  \
# 0                  Nouakchott  18.08581  -15.97850               PPLC
# ...

# %%
sns.boxplot(df1["precision_code"])
# Out:
# C:\Users\manas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='precision_code'>

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6185    False
# 6186    False
# 6187    False
# 6188    False
# 6189    False
# Length: 6190, dtype: bool

# %%
df1.to_csv("cleaneddataodd.csv")

# %%
df1
# Out:
#       project_id project_location_id  precision_code  geoname_id  \
# 0              1           1_2377450               1     2377450
# 1              1           1_2376719               1     2376719
# 2              1           1_2378538               1     2378538
# 3              1           1_2378080               6     2378080
# 4              3           3_2377450               1     2377450
# ...          ...                 ...             ...         ...
# 6185       48940        48940_927384               8      927384
# 6186       49081       49081_7521311               4     7521311
# 6187       49081       49081_1721906               1     1721906
# 6188       49081       49081_1715348               1     1715348
# 6189       49081       49081_1694008               8     1694008
#
#                    place_name  latitude  longitude location_type_code  \
# 0                  Nouakchott  18.08581  -15.97850               PPLC
# ...
