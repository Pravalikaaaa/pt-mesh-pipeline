# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
def logistic(x):
    return 1.0/1+np.exp(-x)

# %%
x=np.linspace(-6,6,1000)
y=logistic(x)

# %%
plt.plot(x,y)
plt.show()

# %%
import pandas as pd

# %%
df =pd.read_csv("cleaneddataodd.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  project_id project_location_id  precision_code  geoname_id  \
# 0           0           1           1_2377450               1     2377450
# 1           1           1           1_2376719               1     2376719
# 2           2           1           1_2378538               1     2378538
# 3           3           1           1_2378080               6     2378080
# 4           4           3           3_2377450               1     2377450
#
#    place_name  latitude  longitude location_type_code  \
# 0  Nouakchott  18.08581  -15.97850               PPLC
# 1    Sélibaby  15.15846  -12.18430               PPLA
# 2       Kiffa  16.61659  -11.40453               PPLA
# 3  Mauritania       NaN        NaN               PCLI
# 4  Nouakchott  18.08581  -15.97850               PPLC
#
#                               location_type_name  ...     loan_type  \
# 0                  capital of a political entity  ...           NaN
# ...

# %%
r=df[['latitude','longitude','geoname_id','location_type_name','location_type_code','location_details']]

# %%
r
# Out:
#       latitude  longitude  geoname_id  \
# 0     18.08581  -15.97850     2377450
# 1     15.15846  -12.18430     2376719
# 2     16.61659  -11.40453     2378538
# 3          NaN        NaN     2378080
# 4     18.08581  -15.97850     2377450
# ...        ...        ...         ...
# 6154       NaN        NaN      927384
# 6155  14.57775  121.04599     7521311
# 6156  15.48586  120.96648     1721906
# 6157   7.07306  125.61278     1715348
# 6158       NaN        NaN     1694008
#
#                                  location_type_name location_type_code  \
# 0                     capital of a political entity               PPLC
# 1     seat of a first-order administrative division               PPLA
# 2     seat of a first-order administrative division               PPLA
# 3                      independent political entity               PCLI
# 4                     capital of a political entity               PPLC
# ...                                             ...                ...
# ...

# %%
r.to_csv("standardizationeven.csv")

# %%
import pandas as pd 
import matplotlib.pyplot as plt 

#reading the csv file 
df = pd.read_csv('standardizationeven.csv') 

#plotting the data as a bar graph 
df.plot.bar(x='latitude', y='longitude', color='green') 

#adding labels and title to the plot 
plt.title('geocode')
plt.xlabel('latitude')
plt.ylabel('longitude')

#showing the plot 
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

#read the csv file
df=pd.read_csv('standardizationeven.csv')

#plot the graph
df.plot()
plt.show()

# %%
data =pd.read_csv('standardizationeven.csv')
data
# Out:
#       Unnamed: 0  latitude  longitude  geoname_id  \
# 0              0  18.08581  -15.97850     2377450
# 1              1  15.15846  -12.18430     2376719
# 2              2  16.61659  -11.40453     2378538
# 3              3       NaN        NaN     2378080
# 4              4  18.08581  -15.97850     2377450
# ...          ...       ...        ...         ...
# 6154        6154       NaN        NaN      927384
# 6155        6155  14.57775  121.04599     7521311
# 6156        6156  15.48586  120.96648     1721906
# 6157        6157   7.07306  125.61278     1715348
# 6158        6158       NaN        NaN     1694008
#
#                                  location_type_name location_type_code  \
# 0                     capital of a political entity               PPLC
# 1     seat of a first-order administrative division               PPLA
# 2     seat of a first-order administrative division               PPLA
# 3                      independent political entity               PCLI
# ...

# %%
data.isnull()
# Out:
#       Unnamed: 0  latitude  longitude  geoname_id  location_type_name  \
# 0          False     False      False       False               False
# 1          False     False      False       False               False
# 2          False     False      False       False               False
# 3          False      True       True       False               False
# 4          False     False      False       False               False
# ...          ...       ...        ...         ...                 ...
# 6154       False      True       True       False               False
# 6155       False     False      False       False               False
# 6156       False     False      False       False               False
# 6157       False     False      False       False               False
# 6158       False      True       True       False               False
#
#       location_type_code  location_details
# 0                  False              True
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0               0
# latitude              1626
# longitude             1626
# geoname_id               0
# location_type_name       0
# location_type_code       0
# location_details      3077
# dtype: int64

# %%
dt=data.dropna()
dt
# Out:
#       Unnamed: 0  latitude  longitude  geoname_id  \
# 4              4  18.08581  -15.97850     2377450
# 5              5 -12.34989   17.30310     3351640
# 7              7  36.75000    4.25000     2475741
# 8              8  36.25000    3.91667     2502951
# 9              9  36.66667    4.91667     2505325
# ...          ...       ...        ...         ...
# 6138        6138  21.75000  102.33333     1653893
# 6139        6139  18.75000  102.41667     1652238
# 6140        6140  20.91667  101.33333     1655561
# 6142        6142  17.96245  102.60985     6695799
# 6153        6153 -29.97592   25.64113     8347553
#
#                        location_type_name location_type_code  \
# 4           capital of a political entity               PPLC
# 5     first-order administrative division               ADM1
# 7     first-order administrative division               ADM1
# 8     first-order administrative division               ADM1
# ...

# %%
dt.to_csv("geocodeclean.csv")
